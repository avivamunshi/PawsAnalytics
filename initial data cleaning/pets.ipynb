# %%
import pandas as pd
import numpy as np

# %%
cats = pd.read_csv("cats_us_23Jan2023_.csv")
cats.head()
# Out:
#          id organization_id  \
# 0  59545481           IL612
# 1  59545478          NY1169
# 2  59545475           FL623
# 3  59545474           GA170
# 4  59545469          PA1036
#
#                                                  url type species     age  \
# 0  https://www.petfinder.com/cat/jasper-59545481/...  Cat     Cat   Young
# 1  https://www.petfinder.com/cat/boots-is-well-do...  Cat     Cat   Young
# 2  https://www.petfinder.com/cat/mr-marvelous-595...  Cat     Cat  Senior
# 3  https://www.petfinder.com/cat/stevie-nicks-595...  Cat     Cat   Adult
# 4  https://www.petfinder.com/cat/rios-59545469/pa...  Cat     Cat   Adult
#
#    gender    size   coat                                               tags  \
# 0    Male  Medium   Long                                                 []
# 1    Male  Medium    NaN  ['Friendly', 'Couch potato', 'Brave', 'Affecti...
# 2    Male   Large    NaN                                                 []
# ...

# %%
cats_col = cats[['id', 'type', 'species', 'age', 'gender', 'size', 'coat', 'name', 'distance', 'breeds.primary', 'breeds.secondary', 'breeds.mixed',
       'breeds.unknown', 'colors.primary', 'animal_type', 'distance',
       'contact.address.city', 'contact.address.state', 'contact.address.postcode','contact.address.country']]
cats_col
# Out:
#               id type species     age  gender    size   coat  \
# 0       59545481  Cat     Cat   Young    Male  Medium   Long
# 1       59545478  Cat     Cat   Young    Male  Medium    NaN
# 2       59545475  Cat     Cat  Senior    Male   Large    NaN
# 3       59545474  Cat     Cat   Adult  Female  Medium    NaN
# 4       59545469  Cat     Cat   Adult    Male  Medium  Short
# ...          ...  ...     ...     ...     ...     ...    ...
# 104395   3087387  Cat     Cat  Senior  Female   Small    NaN
# 104396   2988531  Cat     Cat   Adult  Female   Large    NaN
# 104397   2939452  Cat     Cat   Young  Female  Medium    NaN
# 104398   2571142  Cat     Cat   Adult  Female  Medium    NaN
# 104399   2482447  Cat     Cat  Senior  Female  Medium    NaN
#
#                                             name  distance  \
# 0                                         Jasper       NaN
# 1       Boots is well... THE best!  FRONT DECLAW       NaN
# ...

# %%
cats_col.groupby(['contact.address.country','contact.address.state']).size() \
        .reset_index(name='count').sort_values(['count'], ascending=False).head(10)
# Out:
#    contact.address.country contact.address.state  count
# 17                      US                    CA  11337
# 58                      US                    TX   6679
# 22                      US                    FL   6604
# 52                      US                    PA   6194
# 48                      US                    NY   5998
# 28                      US                    IL   4656
# 49                      US                    OH   4440
# 36                      US                    MI   4147
# 45                      US                    NJ   4002
# 60                      US                    VA   3415

# %%
dogs = pd.read_csv("dogs_us_23Jan2023_.csv")
dogs.head()
# Out:
#          id organization_id  \
# 0  59541454           ON588
# 1  59541453            SC11
# 2  59541450          CA2999
# 3  59541447           CT566
# 4  59541446           TN850
#
#                                                  url type species    age  \
# 0  https://www.petfinder.com/dog/daisy-59541454/o...  Dog     Dog  Adult
# 1  https://www.petfinder.com/dog/happy-nov-22-595...  Dog     Dog  Adult
# 2  https://www.petfinder.com/dog/bonbom-59541450/...  Dog     Dog  Young
# 3  https://www.petfinder.com/dog/sugar-59541447/n...  Dog     Dog   Baby
# 4  https://www.petfinder.com/dog/darling-59541446...  Dog     Dog  Adult
#
#    gender    size    coat                                               tags  \
# 0  Female   Small   Short            ['Friendly', 'Affectionate', 'Playful']
# 1    Male   Large     NaN                                                 []
# 2  Female   Small     NaN  ['Loyal', 'Playful', 'Smart', 'Protective', 'B...
# ...

# %%
dogs.columns
# Out:
# Index(['id', 'organization_id', 'url', 'type', 'species', 'age', 'gender',
#        'size', 'coat', 'tags', 'name', 'description', 'organization_animal_id',
#        'photos', 'videos', 'status', 'status_changed_at', 'published_at',
#        'distance', 'breeds.primary', 'breeds.secondary', 'breeds.mixed',
#        'breeds.unknown', 'colors.primary', 'colors.secondary',
#        'colors.tertiary', 'attributes.spayed_neutered',
#        'attributes.house_trained', 'attributes.declawed',
#        'attributes.special_needs', 'attributes.shots_current',
#        'environment.children', 'environment.dogs', 'environment.cats',
#        'primary_photo_cropped.small', 'primary_photo_cropped.medium',
#        'primary_photo_cropped.large', 'primary_photo_cropped.full',
#        'contact.email', 'contact.phone', 'contact.address.address1',
#        'contact.address.address2', 'contact.address.city',
#        'contact.address.state', 'contact.address.postcode',
# ...

# %%
dogs_col = dogs[['id', 'type', 'species', 'age', 'gender', 'size', 'coat', 'name', 'distance', 'breeds.primary', 'breeds.secondary', 'breeds.mixed',
       'breeds.unknown', 'colors.primary', 'animal_type',
       'contact.address.city', 'contact.address.state', 'contact.address.postcode','contact.address.country']]
dogs_col
# Out:
#              id type species    age  gender    size    coat          name  \
# 0      59541454  Dog     Dog  Adult  Female   Small   Short         Daisy
# 1      59541453  Dog     Dog  Adult    Male   Large     NaN  Happy Nov 22
# 2      59541450  Dog     Dog  Young  Female   Small     NaN        Bonbom
# 3      59541447  Dog     Dog   Baby  Female   Large  Medium         Sugar
# 4      59541446  Dog     Dog  Adult  Female  Medium     NaN       Darling
# ...         ...  ...     ...    ...     ...     ...     ...           ...
# 90195  58111223  Dog     Dog  Adult    Male  Medium     NaN         Heath
# 90196  58111161  Dog     Dog  Young    Male  Medium   Short         Lucky
# 90197  58111146  Dog     Dog  Adult    Male  Medium     NaN         Ralph
# 90198  58111147  Dog     Dog  Adult    Male  Medium     NaN         Donny
# 90199  58111120  Dog     Dog  Adult    Male   Large   Short        Shadow
#
#        distance        breeds.primary breeds.secondary  breeds.mixed  \
# ...

# %%
# dogs_col.groupby(['contact.address.country','contact.address.state']).size() \
#         .reset_index(name='count').sort_values(['count'], ascending=False).head(10)
print(len(dogs_col))
dogs_col[dogs_col['colors.primary'].isna()]
# Out:
# 90200
#              id type species    age  gender    size    coat            name  \
# 1      59541453  Dog     Dog  Adult    Male   Large     NaN    Happy Nov 22
# 11     59541431  Dog     Dog  Adult  Female  Medium     NaN           Molly
# 15     59541419  Dog     Dog   Baby  Female   Large     NaN           Bluey
# 18     59541415  Dog     Dog  Young  Female   Small  Medium  Little Brandy
# 22     59541407  Dog     Dog   Baby  Female   Large     NaN         Pretzel
# ...         ...  ...     ...    ...     ...     ...     ...             ...
# 90190  58111575  Dog     Dog  Young  Female  Medium     NaN           MALTA
# 90191  58111329  Dog     Dog  Young    Male   Large     NaN           CREED
# 90197  58111146  Dog     Dog  Adult    Male  Medium     NaN           Ralph
# 90198  58111147  Dog     Dog  Adult    Male  Medium     NaN           Donny
# 90199  58111120  Dog     Dog  Adult    Male   Large   Short          Shadow
#
# ...

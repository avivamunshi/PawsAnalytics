# %%
import pandas as pd
import numpy as np

# %%
dogs = pd.read_csv("dogs_us_23Jan2023_.csv")
dogs['breeds.primary'] = dogs['breeds.primary'].str.lower()
dogs.head(5)
# Out:
#          id organization_id  \
# 0  59541454           ON588
# 1  59541453            SC11
# 2  59541450          CA2999
# 3  59541447           CT566
# 4  59541446           TN850
#
#                                                  url type species    age  \
# 0  https://www.petfinder.com/dog/daisy-59541454/o...  Dog     Dog  Adult
# 1  https://www.petfinder.com/dog/happy-nov-22-595...  Dog     Dog  Adult
# 2  https://www.petfinder.com/dog/bonbom-59541450/...  Dog     Dog  Young
# 3  https://www.petfinder.com/dog/sugar-59541447/n...  Dog     Dog   Baby
# 4  https://www.petfinder.com/dog/darling-59541446...  Dog     Dog  Adult
#
#    gender    size    coat                                               tags  \
# 0  Female   Small   Short            ['Friendly', 'Affectionate', 'Playful']
# 1    Male   Large     NaN                                                 []
# 2  Female   Small     NaN  ['Loyal', 'Playful', 'Smart', 'Protective', 'B...
# 3  Female   Large  Medium  ['Friendly', 'Affectionate', 'Loyal', 'Gentle'...
# 4  Female  Medium     NaN                  ['At Risk', 'Heartworm Positive']
#
#    ... contact.address.address1 contact.address.address2 contact.address.city  \
# 0  ...                      NaN                      NaN              Toronto
# 1  ...                      NaN                      NaN              Pacolet
# 2  ...                      NaN                      NaN               Ramona
# 3  ...                      NaN                      NaN              Chatham
# 4  ...   2350 Appling City Cove                      NaN              Memphis
#
#   contact.address.state contact.address.postcode contact.address.country  \
# 0                    ON                  M4S 0A7                      CA
# 1                    SC                    29372                      US
# 2                    CA                    92065                      US
# 3                    NJ                    07928                      US
# 4                    TN                    38133                      US
#
#   animal_id animal_type  organization_id.1 primary_photo_cropped
# 0  59541454         dog              on588                   NaN
# 1  59541453         dog               sc11                   NaN
# 2  59541450         dog             ca2999                   NaN
# 3  59541447         dog              ct566                   NaN
# 4  59541446         dog              tn850                   NaN
#
# [5 rows x 50 columns]

# %%
akc = pd.read_csv("akc_updated.csv")
akc.rename(columns = {'Unnamed: 0': 'Breed'}, inplace = True)
akc['Breed'] = akc['Breed'].str.lower()
akc.head(5)
# Out:
#               Breed                                        description  \
# 0     affenpinscher  The Affen’s apish look has been described many...
# 1      afghan hound  The Afghan Hound is an ancient breed, his whol...
# 2  airedale terrier  The Airedale Terrier is the largest of all ter...
# 3             akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4  alaskan malamute  The Alaskan Malamute stands 23 to 25 inches at...
#
#                                  temperament popularity  min_height  \
# 0        Confident, Famously Funny, Fearless        148       22.86
# 1  Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2               Friendly, Clever, Courageous         60       58.42
# 3    Courageous, Dignified, Profoundly Loyal         47       60.96
# 4               Affectionate, Loyal, Playful         58       58.42
#
#    max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0       29.21    3.175147    4.535924            12.0            15.0  ...
# 1       68.58   22.679619   27.215542            12.0            15.0  ...
# 2       58.42   22.679619   31.751466            11.0            14.0  ...
# 3       71.12   31.751466   58.967008            10.0            13.0  ...
# 4       63.50   34.019428   38.555351            10.0            14.0  ...
#
#   grooming_frequency_value  grooming_frequency_category shedding_value  \
# 0                      0.6    2-3 Times a Week Brushing            0.6
# 1                      0.8               Daily Brushing            0.2
# 2                      0.6    2-3 Times a Week Brushing            0.4
# 3                      0.8               Daily Brushing            0.6
# 4                      0.6    2-3 Times a Week Brushing            0.6
#
#    shedding_category energy_level_value  energy_level_category  \
# 0           Seasonal                0.6       Regular Exercise
# 1         Infrequent                0.8              Energetic
# 2         Occasional                0.6       Regular Exercise
# 3           Seasonal                0.8              Energetic
# 4           Seasonal                0.8              Energetic
#
#   trainability_value  trainability_category demeanor_value  demeanor_category
# 0                0.8          Easy Training            1.0           Outgoing
# 1                0.2        May be Stubborn            0.2         Aloof/Wary
# 2                1.0        Eager to Please            0.8           Friendly
# 3                1.0        Eager to Please            0.6   Alert/Responsive
# 4                0.4            Independent            0.8           Friendly
#
# [5 rows x 21 columns]

# %%
df_merged=pd.merge(dogs, akc, left_on='breeds.primary', right_on='Breed', how='left')
df_merged.head(5)
# Out:
#          id organization_id  \
# 0  59541454           ON588
# 1  59541453            SC11
# 2  59541450          CA2999
# 3  59541447           CT566
# 4  59541446           TN850
#
#                                                  url type species    age  \
# 0  https://www.petfinder.com/dog/daisy-59541454/o...  Dog     Dog  Adult
# 1  https://www.petfinder.com/dog/happy-nov-22-595...  Dog     Dog  Adult
# 2  https://www.petfinder.com/dog/bonbom-59541450/...  Dog     Dog  Young
# 3  https://www.petfinder.com/dog/sugar-59541447/n...  Dog     Dog   Baby
# 4  https://www.petfinder.com/dog/darling-59541446...  Dog     Dog  Adult
#
#    gender    size    coat                                               tags  \
# 0  Female   Small   Short            ['Friendly', 'Affectionate', 'Playful']
# 1    Male   Large     NaN                                                 []
# 2  Female   Small     NaN  ['Loyal', 'Playful', 'Smart', 'Protective', 'B...
# 3  Female   Large  Medium  ['Friendly', 'Affectionate', 'Loyal', 'Gentle'...
# 4  Female  Medium     NaN                  ['At Risk', 'Heartworm Positive']
#
#    ... grooming_frequency_value grooming_frequency_category shedding_value  \
# 0  ...                      0.4             Weekly Brushing            0.4
# 1  ...                      1.0      Specialty/Professional            0.2
# 2  ...                      1.0      Specialty/Professional            0.2
# 3  ...                      0.4             Weekly Brushing            0.6
# 4  ...                      NaN                         NaN            NaN
#
#   shedding_category energy_level_value   energy_level_category  \
# 0        Occasional                1.0  Needs Lots of Activity
# 1        Infrequent                0.6        Regular Exercise
# 2        Infrequent                0.6        Regular Exercise
# 3          Seasonal                1.0  Needs Lots of Activity
# 4               NaN                NaN                     NaN
#
#   trainability_value trainability_category  demeanor_value  \
# 0                0.6             Agreeable             0.8
# 1                1.0       Eager to Please             0.8
# 2                1.0       Eager to Please             0.8
# 3                0.4           Independent             0.4
# 4                NaN                   NaN             NaN
#
#          demeanor_category
# 0                 Friendly
# 1                 Friendly
# 2                 Friendly
# 3  Reserved with Strangers
# 4                      NaN
#
# [5 rows x 71 columns]

# %%
df_merged.columns
# Out:
# Index(['id', 'organization_id', 'url', 'type', 'species', 'age', 'gender',
#        'size', 'coat', 'tags', 'name', 'description_x',
#        'organization_animal_id', 'photos', 'videos', 'status',
#        'status_changed_at', 'published_at', 'distance', 'breeds.primary',
#        'breeds.secondary', 'breeds.mixed', 'breeds.unknown', 'colors.primary',
#        'colors.secondary', 'colors.tertiary', 'attributes.spayed_neutered',
#        'attributes.house_trained', 'attributes.declawed',
#        'attributes.special_needs', 'attributes.shots_current',
#        'environment.children', 'environment.dogs', 'environment.cats',
#        'primary_photo_cropped.small', 'primary_photo_cropped.medium',
#        'primary_photo_cropped.large', 'primary_photo_cropped.full',
#        'contact.email', 'contact.phone', 'contact.address.address1',
#        'contact.address.address2', 'contact.address.city',
#        'contact.address.state', 'contact.address.postcode',
#        'contact.address.country', 'animal_id', 'animal_type',
#        'organization_id.1', 'primary_photo_cropped', 'Breed', 'description_y',
#        'temperament', 'popularity', 'min_height', 'max_height', 'min_weight',
#        'max_weight', 'min_expectancy', 'max_expectancy', 'group',
#        'grooming_frequency_value', 'grooming_frequency_category',
#        'shedding_value', 'shedding_category', 'energy_level_value',
#        'energy_level_category', 'trainability_value', 'trainability_category',
#        'demeanor_value', 'demeanor_category'],
#       dtype='object')

# %%
df_filtered = df_merged[['id', 'type', 'species', 'age', 'gender', 'size', 'coat', 'name', 'distance', 'breeds.primary', 'breeds.secondary', 'breeds.mixed','breeds.unknown', 'colors.primary', 'animal_type', 'distance','contact.address.city', 'contact.address.state', 'contact.address.postcode','contact.address.country','Breed', 'description_y','temperament', 'popularity', 'min_height', 'max_height', 'min_weight','max_weight', 'min_expectancy', 'max_expectancy', 'group','grooming_frequency_value', 'grooming_frequency_category','shedding_value', 'shedding_category', 'energy_level_value','energy_level_category', 'trainability_value', 'trainability_category','demeanor_value', 'demeanor_category']]
df_filtered.head(10)
# Out:
#          id type species    age  gender    size    coat          name  \
# 0  59541454  Dog     Dog  Adult  Female   Small   Short         Daisy
# 1  59541453  Dog     Dog  Adult    Male   Large     NaN  Happy Nov 22
# 2  59541450  Dog     Dog  Young  Female   Small     NaN        Bonbom
# 3  59541447  Dog     Dog   Baby  Female   Large  Medium         Sugar
# 4  59541446  Dog     Dog  Adult  Female  Medium     NaN       Darling
# 5  59541444  Dog     Dog  Young    Male   Large     NaN         Lucky
# 6  59541438  Dog     Dog   Baby    Male   Large   Short        Davis
# 7  59541435  Dog     Dog  Adult    Male   Large  Medium       HATCHI
# 8  59414553  Dog     Dog  Young    Male   Large   Short   Bogey Bear
# 9  59541433  Dog     Dog   Baby    Male   Large     NaN        Drake
#
#    distance        breeds.primary  ... grooming_frequency_value  \
# 0       NaN  jack russell terrier  ...                      0.4
# 1       NaN       standard poodle  ...                      1.0
# 2       NaN                poodle  ...                      1.0
# 3       NaN        great pyrenees  ...                      0.4
# 4       NaN           mixed breed  ...                      NaN
# 5       NaN        great pyrenees  ...                      0.4
# 6       NaN                 hound  ...                      NaN
# 7       NaN                 akita  ...                      0.8
# 8       NaN    labrador retriever  ...                      0.4
# 9       NaN                 hound  ...                      NaN
#
#    grooming_frequency_category  shedding_value shedding_category  \
# 0              Weekly Brushing             0.4        Occasional
# 1       Specialty/Professional             0.2        Infrequent
# 2       Specialty/Professional             0.2        Infrequent
# 3              Weekly Brushing             0.6          Seasonal
# 4                          NaN             NaN               NaN
# 5              Weekly Brushing             0.6          Seasonal
# 6                          NaN             NaN               NaN
# 7               Daily Brushing             0.6          Seasonal
# 8              Weekly Brushing             0.8         Regularly
# 9                          NaN             NaN               NaN
#
#   energy_level_value   energy_level_category trainability_value  \
# 0                1.0  Needs Lots of Activity                0.6
# 1                0.6        Regular Exercise                1.0
# 2                0.6        Regular Exercise                1.0
# 3                1.0  Needs Lots of Activity                0.4
# 4                NaN                     NaN                NaN
# 5                1.0  Needs Lots of Activity                0.4
# 6                NaN                     NaN                NaN
# 7                0.8               Energetic                1.0
# 8                1.0  Needs Lots of Activity                1.0
# 9                NaN                     NaN                NaN
#
#   trainability_category demeanor_value        demeanor_category
# 0             Agreeable            0.8                 Friendly
# 1       Eager to Please            0.8                 Friendly
# 2       Eager to Please            0.8                 Friendly
# 3           Independent            0.4  Reserved with Strangers
# 4                   NaN            NaN                      NaN
# 5           Independent            0.4  Reserved with Strangers
# 6                   NaN            NaN                      NaN
# 7       Eager to Please            0.6         Alert/Responsive
# 8       Eager to Please            1.0                 Outgoing
# 9                   NaN            NaN                      NaN
#
# [10 rows x 41 columns]

# %%
df_filtered.to_csv("cleaned_joined_akc_pf.csv", index=False, sep='|')

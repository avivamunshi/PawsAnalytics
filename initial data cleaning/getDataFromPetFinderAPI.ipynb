# %%
import requests
import json
import pandas as pd
import petpy

# %%
key = "UPDATE"
secret = "UPDATE"
pf = petpy.Petfinder(key=key, secret=secret)

# %%
cats = pf.animals(animal_type='cat', gender='female', status='adoptable', location='Seattle, WA', distance=10,
                  results_per_page=50, pages=None, return_df=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cats = pf.animals(animal_type='cat', gender='female', status='adoptable', location='Seattle, WA', distance=10,
#       2                   results_per_page=50, pages=None, return_df=True)
#
# File ~/opt/anaconda3/envs/data515/lib/python3.9/site-packages/petpy/api.py:506, in Petfinder.animals(self, animal_id, animal_type, breed, size, gender, age, color, coat, status, name, organization_id, location, distance, good_with_children, good_with_dogs, good_with_cats, house_trained, declawed, special_needs, before_date, after_date, sort, pages, results_per_page, return_df)
#     498 params['page'] = 1
#     500 r = _get_result(url,
#     501                 headers={
#     502                     'Authorization': 'Bearer ' + self._auth
#     503                 },
#     504                 params=params)
# ...

# %%
cats.head(10)
# Out:
#          id  organization_id  \
# 0  59539835           TX2673
# 1  59537236             WA06
# 2  59535959             WA27
# 3  59535960             WA27
# 4  59535298             WA40
# 5  59525662           TX2673
# 6  59520546            WA119
# 7  59519590           TX2305
# 8  59508389             WA40
# 9  59505957             WA27
#
#                                                  url type species    age  \
# 0  https://www.petfinder.com/cat/tab-tab-59539835...  Cat     Cat   Baby
# 1  https://www.petfinder.com/cat/winter-59537236/...  Cat     Cat  Adult
# 2  https://www.petfinder.com/cat/kitty-kitty-5953...  Cat     Cat  Young
# 3  https://www.petfinder.com/cat/luna-59535960/wa...  Cat     Cat  Young
# 4  https://www.petfinder.com/cat/opal-and-batilde...  Cat     Cat   Baby
# 5  https://www.petfinder.com/cat/boo-bear-and-bun...  Cat     Cat  Adult
# 6  https://www.petfinder.com/cat/amaretto-5952054...  Cat     Cat  Adult
# ...

# %%
dogs_seattle = pf.animals(animal_type='dog', status='adoptable', location='Seattle, WA', distance=100, pages=None)

# %%
cats_df_all_results = pf.animals(animal_type='cat', gender='female', status='adoptable', 
                                 location='Seattle, WA', distance=300, pages=None, return_df=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 cats_df_all_results = pf.animals(animal_type='cat', gender='female', status='adoptable',
#       2                                  location='Seattle, WA', distance=300, pages=None, return_df=True)
#
# File ~/opt/anaconda3/envs/data515/lib/python3.9/site-packages/petpy/api.py:506, in Petfinder.animals(self, animal_id, animal_type, breed, size, gender, age, color, coat, status, name, organization_id, location, distance, good_with_children, good_with_dogs, good_with_cats, house_trained, declawed, special_needs, before_date, after_date, sort, pages, results_per_page, return_df)
#     498 params['page'] = 1
#     500 r = _get_result(url,
#     501                 headers={
#     502                     'Authorization': 'Bearer ' + self._auth
#     503                 },
# ...

# %%
cats_df_all_results
# Out:
#             id  organization_id  \
# 0     59541430            BC136
# 1     59541233            BC136
# 2     59541101            WA748
# 3     59541025            BC136
# 4     59540807            BC136
# ...        ...              ...
# 1295  19832813            WA309
# 1296  19549107            WA309
# 1297  17577913            WA309
# 1298  14265512            OR245
# 1299  10954554            BC114
#
#                                                     url type species     age  \
# 0     https://www.petfinder.com/cat/wassail-59541430...  Cat     Cat   Young
# 1     https://www.petfinder.com/cat/greyhound-595412...  Cat     Cat  Senior
# 2     https://www.petfinder.com/cat/amaretto-and-mar...  Cat     Cat    Baby
# 3     https://www.petfinder.com/cat/firecracker-5954...  Cat     Cat   Adult
# 4     https://www.petfinder.com/cat/tayshia-59540807...  Cat     Cat   Adult
# ...                                                 ...  ...     ...     ...
# ...

# %%
cats_df_all_results_wa = pf.animals(animal_type='cat', gender='female', status='adoptable', 
                                 location='WA', pages=None, return_df=True)

# %%
cats_df_all_results_wa
# Out:
#            id  organization_id  \
# 0    59539835           TX2673
# 1    59537236             WA06
# 2    59537167            WA470
# 3    59537149            WA470
# 4    59537148            WA470
# ..        ...              ...
# 312  48321744            WA500
# 313  45199461             WA73
# 314  34214605            WA638
# 315  34196383            WA638
# 316  34147331            WA638
#
#                                                    url type species    age  \
# 0    https://www.petfinder.com/cat/tab-tab-59539835...  Cat     Cat   Baby
# 1    https://www.petfinder.com/cat/winter-59537236/...  Cat     Cat  Adult
# 2    https://www.petfinder.com/cat/catherine-595371...  Cat     Cat  Adult
# 3    https://www.petfinder.com/cat/trix-59537149/wa...  Cat     Cat   Baby
# 4    https://www.petfinder.com/cat/tot-59537148/wa/...  Cat     Cat   Baby
# ..                                                 ...  ...     ...    ...
# ...

# %%
dogs_df_all_results_wa = pf.animals(animal_type='dog', status='adoptable', 
                                 location='WA', pages=None, return_df=True)

# %%
dogs_df_all_results_wa
# Out:
#             id  organization_id  \
# 0     59540715            WA546
# 1     59540445            WA139
# 2     59538675            WA749
# 3     59538676            WA749
# 4     59537687             WA47
# ...        ...              ...
# 1524  36789542           TX1956
# 1525  24706570            WA139
# 1526  22646089            WA139
# 1527  21588150            WA139
# 1528  12965366            WA427
#
#                                                     url type species     age  \
# 0     https://www.petfinder.com/dog/peach-59540715/w...  Dog     Dog   Adult
# 1     https://www.petfinder.com/dog/jackie-59540445/...  Dog     Dog   Adult
# 2     https://www.petfinder.com/dog/ranger-59538675/...  Dog     Dog    Baby
# 3     https://www.petfinder.com/dog/rex-59538676/wa/...  Dog     Dog    Baby
# 4     https://www.petfinder.com/dog/nozomi-59537687/...  Dog     Dog   Young
# ...                                                 ...  ...     ...     ...
# ...

# %%
dogs_df_all_results_us = pf.animals(animal_type='dog', status='adoptable', 
                                 pages=None, return_df=True)

# %%
cats_df_all_results_us = pf.animals(animal_type='cat', status='adoptable', 
                                 pages=None, return_df=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 cats_df_all_results_us = pf.animals(animal_type='cat', status='adoptable',
#       2                                  pages=None, return_df=True)
#
# File ~/opt/anaconda3/envs/data515/lib/python3.9/site-packages/petpy/api.py:506, in Petfinder.animals(self, animal_id, animal_type, breed, size, gender, age, color, coat, status, name, organization_id, location, distance, good_with_children, good_with_dogs, good_with_cats, house_trained, declawed, special_needs, before_date, after_date, sort, pages, results_per_page, return_df)
#     498 params['page'] = 1
#     500 r = _get_result(url,
#     501                 headers={
#     502                     'Authorization': 'Bearer ' + self._auth
#     503                 },
#     504                 params=params)
# --> 506 animals = r.json()['animals']
# ...

# %%
dogs_df_all_results_us
# Out:
#              id organization_id  \
# 0      59541454           ON588
# 1      59541453            SC11
# 2      59541450          CA2999
# 3      59541447           CT566
# 4      59541446           TN850
# ...         ...             ...
# 90195  58111223           IL158
# 90196  58111161          CA2919
# 90197  58111146           IN213
# 90198  58111147           IN213
# 90199  58111120            QC79
#
#                                                      url type species    age  \
# 0      https://www.petfinder.com/dog/daisy-59541454/o...  Dog     Dog  Adult
# 1      https://www.petfinder.com/dog/happy-nov-22-595...  Dog     Dog  Adult
# 2      https://www.petfinder.com/dog/bonbom-59541450/...  Dog     Dog  Young
# 3      https://www.petfinder.com/dog/sugar-59541447/n...  Dog     Dog   Baby
# 4      https://www.petfinder.com/dog/darling-59541446...  Dog     Dog  Adult
# ...                                                  ...  ...     ...    ...
# ...

# %%
dogs_df_all_results_us.to_csv("dogs_us_23Jan2023_.csv", index=False)
